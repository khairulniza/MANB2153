# %% [markdown]
# <a href="https://colab.research.google.com/github/khairulniza/MANB2153/blob/master/Iris_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split



df=load_iris()
y=to_categorical(df['target'])
X=df['data']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33, random_state=42)

model = Sequential()
# Dense(64) is a fully-connected layer with 64 hidden units.
# in the first layer, you must specify the expected input data shape:
# here, 20-dimensional vectors.
model.add(Dense(64, activation='relu', input_dim=4))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

model.fit(X_train, y_train,epochs=100,batch_size=128)
score = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 1s 6ms/step - loss: 1.5512 - acc: 0.3600
# Epoch 2/100
# 100/100 [==============================] - 0s 27us/step - loss: 1.6240 - acc: 0.3400
# Epoch 3/100
# 100/100 [==============================] - 0s 23us/step - loss: 1.4574 - acc: 0.3600
# Epoch 4/100
# 100/100 [==============================] - 0s 20us/step - loss: 1.5445 - acc: 0.3300
# Epoch 5/100
# 100/100 [==============================] - 0s 17us/step - loss: 1.3910 - acc: 0.4000
# Epoch 6/100
# 100/100 [==============================] - 0s 21us/step - loss: 1.3692 - acc: 0.3200
# Epoch 7/100
# 100/100 [==============================] - 0s 22us/step - loss: 1.2444 - acc: 0.4000
# Epoch 8/100
# 100/100 [==============================] - 0s 19us/step - loss: 1.1328 - acc: 0.4100
# Epoch 9/100
# 100/100 [==============================] - 0s 19us/step - loss: 1.1819 - acc: 0.4200
# Epoch 10/100
# ...
